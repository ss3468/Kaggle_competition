# %%
#Imported Packages:

#Generic
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

#Data Modeling
from sklearn.model_selection import train_test_split
from sklearn import metrics

#Data Visualization
from scipy.stats import iqr
from scipy.stats import skew
from scipy.stats import kurtosis, shapiro
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_data=pd.read_csv('train.csv',keep_default_na=False,na_values=[" ", "#N/A", "#N/A N/A", "#NA", "-1.#IND", "-1.#QNAN", "-NaN", "-nan", "1.#IND", "1.#QNAN", "<NA>", "N/A", "NULL", "NaN", "n/a", "nan", "null","NA"])
test_data=pd.read_csv('test.csv',keep_default_na=False,na_values=[" ", "#N/A", "#N/A N/A", "#NA", "-1.#IND", "-1.#QNAN", "-NaN", "-nan", "1.#IND", "1.#QNAN", "<NA>", "N/A", "NULL", "NaN", "n/a", "nan", "null","NA"])
default_NA={'Alley':'NA','BsmtQual':'NA','BsmtCond':'NA','BsmtExposure':'NA',
            'BsmtFinType1':'NA','BsmtFinType2':'NA','FireplaceQu':'NA',
            'GarageType':'NA','GarageFinish':'NA',
            'GarageQual':'NA','GarageCond':'NA','PoolQC':'NA','Fence':'NA','MiscFeature':'NA'}
train_data=train_data.fillna(default_NA)
test_data=test_data.fillna(default_NA)

# %%
nulls = train_data.isnull().sum().to_frame()
for index, row in nulls.iterrows():
    if row[0] > 0:
        print(index, row[0]/len(train_data))
    else:
        continue
# Out:
# LotFrontage 0.1773972602739726
# MasVnrType 0.005479452054794521
# MasVnrArea 0.005479452054794521
# Electrical 0.0006849315068493151
# GarageYrBlt 0.05547945205479452

# %%
nulls = test_data.isnull().sum().to_frame()
for index, row in nulls.iterrows():
    if row[0] > 0:
        print(index, row[0])
    else:
        continue
# Out:
# MSZoning 4
# LotFrontage 227
# Utilities 2
# Exterior1st 1
# Exterior2nd 1
# MasVnrType 16
# MasVnrArea 15
# BsmtFinSF1 1
# BsmtFinSF2 1
# BsmtUnfSF 1
# TotalBsmtSF 1
# BsmtFullBath 2
# BsmtHalfBath 2
# KitchenQual 1
# Functional 2
# GarageYrBlt 78
# GarageCars 1
# GarageArea 1
# SaleType 1

# %%
plt.figure(figsize=(10, 6))
sns.histplot(train_data[train_data['2ndFlrSF']!=0]['2ndFlrSF'], kde=True, bins=30)
plt.title(f'Distribution of 2ndFlrSF')
plt.xlabel('2ndFlrSF')
plt.ylabel('Frequency')
plt.show()

# Calculate and print skewness
feature_skewness = skew(train_data[train_data['2ndFlrSF']!=0]['2ndFlrSF'].dropna())  # dropna() to ignore missing values
print(f'Skewness of 2ndFlrSF: {feature_skewness}')
# Out:
# Skewness of 3SsnPorch: 1.205196475115787

# %%
plt.figure(figsize=(10, 6))
sns.histplot(np.sqrt(train_data[train_data['3SsnPorch']!=0]['3SsnPorch']), kde=True, bins=30)
plt.title(f'Distribution of 3SsnPorch')
plt.xlabel('3SsnPorch')
plt.ylabel('Frequency')
plt.show()

# Calculate and print skewness
feature_skewness = skew(np.sqrt(train_data[train_data['3SsnPorch']!=0]['3SsnPorch']).dropna())  # dropna() to ignore missing values
print(f'Skewness of 3SsnPorch: {feature_skewness}')
# Out:
# Skewness of 3SsnPorch: 0.0995471333864055

# %% [markdown]
# # Generate synthetic data

# %%
from sklearn.utils import resample
training_augmented=train_data.copy()
n_augmented_samples = len(train_data)
print(train_data.shape)
X_train_bootstrap, y_train_bootstrap = resample(train_data.loc[:,train_data.columns!='SalePrice'],train_data.loc[:,'SalePrice'], n_samples=n_augmented_samples, replace=True, random_state=42)
synthetic_data=pd.concat([X_train_bootstrap, y_train_bootstrap], axis=1)
synthetic_data['Id']=(synthetic_data['Id'].astype(str) + '_' + (synthetic_data.groupby('Id').cumcount() + 1).astype(str))
#synthetic_data['SalePrice_og']=synthetic_data['SalePrice']
synthetic_data['BsmtFinSF1'] = np.where(synthetic_data['BsmtFinType1'].isin(['NA', 'Unf']),synthetic_data['BsmtFinSF1'],np.power(np.sqrt(synthetic_data['BsmtFinSF1']) + np.random.normal(0, np.sqrt(train_data['BsmtFinSF1']).std() * 0.01, size=len(synthetic_data)), 2))
synthetic_data['BsmtUnfSF']=np.power((np.sqrt(synthetic_data['BsmtUnfSF'])+np.random.normal(0,np.sqrt(train_data['BsmtUnfSF']).std()*0.01,size=len(synthetic_data))),2)
synthetic_data['TotalBsmtSF']=synthetic_data[['BsmtFinSF1','BsmtFinSF2','BsmtUnfSF']].sum(axis=1, skipna=True)
synthetic_data['GrLivArea']=np.power((np.sqrt(synthetic_data['GrLivArea'])+np.random.normal(0,np.sqrt(train_data['GrLivArea']).std()*0.01,size=len(synthetic_data))),2)
synthetic_data['1stFlrSF']=np.expm1(np.log1p(synthetic_data['1stFlrSF'])+np.random.normal(0,np.log1p(train_data['1stFlrSF']).std()*0.01,size=len(synthetic_data)))
synthetic_data['MasVnrArea']=np.expm1(np.log1p(synthetic_data['MasVnrArea'])+np.random.normal(0,np.log1p(train_data['MasVnrArea']).std()*0.01,size=len(synthetic_data)))
synthetic_data['LotArea']=np.expm1(np.log1p(synthetic_data['LotArea'])+np.random.normal(0,np.log1p(train_data['LotArea']).std()*0.01,size=len(synthetic_data)))
synthetic_data['LotFrontage']=np.power((np.sqrt(synthetic_data['LotFrontage'])+np.random.normal(0,np.sqrt(train_data['LotFrontage']).std()*0.01,size=len(synthetic_data))),2)
synthetic_data['SalePrice']=synthetic_data['SalePrice']*np.exp(np.random.normal(0,(np.log(train_data['SalePrice']/100000)).std() * 0.01, size=len(synthetic_data)))

synthetic_data.to_csv('synthetic_data.csv',index=False)
synthetic_data
# Out:
# (1460, 81)
#           Id  MSSubClass MSZoning  LotFrontage       LotArea Street Alley  \
# 1126  1127_1         120       RL    53.066028   3679.611334   Pave    NA
# 1459  1460_1          20       RL    75.362877   9989.897568   Pave    NA
# 860    861_1          50       RL    55.035986   7678.646704   Pave    NA
# 1294  1295_1          20       RL    60.110297   8204.497680   Pave    NA
# 1130  1131_1          50       RL    64.927326   7818.089481   Pave    NA
# ...      ...         ...      ...          ...           ...    ...   ...
# 1112  1113_1          20       RL    72.757550   7049.580102   Pave    NA
# 1291  1292_3         160       RM    21.069614   1672.947651   Pave    NA
# 488    489_2         190       RL    59.967864  10746.026542   Pave    NA
# 46      47_5          50       RL    48.140241  12885.365555   Pave    NA
# 1311  1312_3          20       RL    68.025975   8846.391468   Pave    NA
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# 1126      Reg         Lvl    AllPub  ...        0     NA     NA          NA
# 1459      Reg         Lvl    AllPub  ...        0     NA     NA          NA
# 860       Reg         Lvl    AllPub  ...        0     NA  GdPrv          NA
# 1294      Reg         Lvl    AllPub  ...        0     NA     NA          NA
# 1130      Reg         Lvl    AllPub  ...        0     NA  MnPrv          NA
# ...       ...         ...       ...  ...      ...    ...    ...         ...
# 1112      IR1         Lvl    AllPub  ...        0     NA     NA          NA
# 1291      Reg         Lvl    AllPub  ...        0     NA     NA          NA
# 488       Reg         Lvl    AllPub  ...        0     NA     NA          NA
# 46        IR1         Lvl    AllPub  ...        0     NA     NA          NA
# 1311      Reg         Lvl    AllPub  ...        0     NA     NA          NA
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition      SalePrice
# 1126       0      6   2009        WD         Normal  174218.269956
# 1459       0      6   2008        WD         Normal  147413.940874
# 860        0      6   2007        WD         Normal  189310.030058
# 1294       0      4   2006        WD         Normal  115380.639440
# 1130       0     12   2009        WD         Normal  136035.109831
# ...      ...    ...    ...       ...            ...            ...
# 1112       0      7   2006        WD         Normal  130130.427995
# 1291       0      2   2009        WD         Normal  120408.594343
# 488        0      5   2006     ConLD         Normal  160576.700224
# 46         0      8   2009        WD        Abnorml  238737.975376
# 1311       0      1   2007       New        Partial  203686.906756
#
# [1460 rows x 81 columns]

# %%
train_data_aug = pd.concat([train_data, synthetic_data], axis=0, ignore_index=True)

# Reset the index
train_data_aug = train_data_aug.reset_index(drop=True)
train_data_aug.to_csv('train_data_aug.csv',index=False)
train_data_aug
# Out:
#           Id  MSSubClass MSZoning  LotFrontage       LotArea Street Alley  \
# 0          1          60       RL    65.000000   8450.000000   Pave    NA
# 1          2          20       RL    80.000000   9600.000000   Pave    NA
# 2          3          60       RL    68.000000  11250.000000   Pave    NA
# 3          4          70       RL    60.000000   9550.000000   Pave    NA
# 4          5          60       RL    84.000000  14260.000000   Pave    NA
# ...      ...         ...      ...          ...           ...    ...   ...
# 2915  1113_1          20       RL    72.757550   7049.580102   Pave    NA
# 2916  1292_3         160       RM    21.069614   1672.947651   Pave    NA
# 2917   489_2         190       RL    59.967864  10746.026542   Pave    NA
# 2918    47_5          50       RL    48.140241  12885.365555   Pave    NA
# 2919  1312_3          20       RL    68.025975   8846.391468   Pave    NA
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  \
# 0         Reg         Lvl    AllPub  ...        0     NA    NA          NA
# 1         Reg         Lvl    AllPub  ...        0     NA    NA          NA
# 2         IR1         Lvl    AllPub  ...        0     NA    NA          NA
# 3         IR1         Lvl    AllPub  ...        0     NA    NA          NA
# 4         IR1         Lvl    AllPub  ...        0     NA    NA          NA
# ...       ...         ...       ...  ...      ...    ...   ...         ...
# 2915      IR1         Lvl    AllPub  ...        0     NA    NA          NA
# 2916      Reg         Lvl    AllPub  ...        0     NA    NA          NA
# 2917      Reg         Lvl    AllPub  ...        0     NA    NA          NA
# 2918      IR1         Lvl    AllPub  ...        0     NA    NA          NA
# 2919      Reg         Lvl    AllPub  ...        0     NA    NA          NA
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition      SalePrice
# 0          0      2   2008        WD         Normal  208500.000000
# 1          0      5   2007        WD         Normal  181500.000000
# 2          0      9   2008        WD         Normal  223500.000000
# 3          0      2   2006        WD        Abnorml  140000.000000
# 4          0     12   2008        WD         Normal  250000.000000
# ...      ...    ...    ...       ...            ...            ...
# 2915       0      7   2006        WD         Normal  130130.427995
# 2916       0      2   2009        WD         Normal  120408.594343
# 2917       0      5   2006     ConLD         Normal  160576.700224
# 2918       0      8   2009        WD        Abnorml  238737.975376
# 2919       0      1   2007       New        Partial  203686.906756
#
# [2920 rows x 81 columns]

# %% [markdown]
# # Split data

# %%
X_train,X_valid,y_train,y_valid=train_test_split(train_data_aug.loc[:,train_data.columns!='SalesPrice'],train_data_aug.loc[:,train_data.columns=='SalesPrice'],test_size=0.2,random_state=42)
training = X_train.join(y_train)
validation = X_valid.join(y_valid)
X_train
# Out:
#           Id  MSSubClass MSZoning  LotFrontage       LotArea Street Alley  \
# 2651   640_2         120       RL    53.314808   3958.064069   Pave    NA
# 1709   151_1          20       RL   120.168346  10277.720194   Pave    NA
# 869      870          60       RL    80.000000   9938.000000   Pave    NA
# 2355     8_1          60       RL          NaN  10372.811187   Pave    NA
# 2915  1113_1          20       RL    72.757550   7049.580102   Pave    NA
# ...      ...         ...      ...          ...           ...    ...   ...
# 1638   973_1         120       RL    55.147984   7899.828740   Pave    NA
# 1095    1096          20       RL    78.000000   9317.000000   Pave    NA
# 1130    1131          50       RL    65.000000   7804.000000   Pave    NA
# 1294    1295          20       RL    60.000000   8172.000000   Pave    NA
# 860      861          50       RL    55.000000   7642.000000   Pave    NA
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# 2651      Reg         Lvl    AllPub  ...        0     NA     NA          NA
# 1709      Reg         Lvl    AllPub  ...        0     NA  MnPrv          NA
# 869       Reg         Lvl    AllPub  ...        0     NA  GdPrv          NA
# 2355      IR1         Lvl    AllPub  ...        0     NA     NA        Shed
# 2915      IR1         Lvl    AllPub  ...        0     NA     NA          NA
# ...       ...         ...       ...  ...      ...    ...    ...         ...
# 1638      Reg         Lvl    AllPub  ...        0     NA     NA          NA
# 1095      IR1         Lvl    AllPub  ...        0     NA     NA          NA
# 1130      Reg         Lvl    AllPub  ...        0     NA  MnPrv          NA
# 1294      Reg         Lvl    AllPub  ...        0     NA     NA          NA
# 860       Reg         Lvl    AllPub  ...        0     NA  GdPrv          NA
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition      SalePrice
# 2651       0     10   2006       New        Partial  265697.251067
# 1709       0      1   2007        WD         Normal  121079.608459
# 869        0      6   2010        WD         Normal  236000.000000
# 2355     350     11   2009        WD         Normal  199711.285054
# 2915       0      7   2006        WD         Normal  130130.427995
# ...      ...    ...    ...       ...            ...            ...
# 1638       0      4   2010        WD         Normal   99067.134982
# 1095       0      3   2007        WD         Normal  176432.000000
# 1130       0     12   2009        WD         Normal  135000.000000
# 1294       0      4   2006        WD         Normal  115000.000000
# 860        0      6   2007        WD         Normal  189950.000000
#
# [2336 rows x 81 columns]

# %%
training.to_csv('training.csv',index=False)
validation.to_csv('validation.csv',index=False)

# %%
nulls = training.isnull().sum().to_frame()
for index, row in nulls.iterrows():
    if row[0] > 0:
        print(index, row[0])
    else:
        continue
# Out:
# LotFrontage 428
# MasVnrType 11
# MasVnrArea 11
# Electrical 1
# GarageYrBlt 123

# %%
nulls = validation.isnull().sum().to_frame()
for index, row in nulls.iterrows():
    if row[0] > 0:
        print(index, row[0])
    else:
        continue
# Out:
# LotFrontage 100
# MasVnrType 3
# MasVnrArea 3
# Electrical 1
# GarageYrBlt 30

# %%
nulls = test_data.isnull().sum().to_frame()
for index, row in nulls.iterrows():
    if row[0] > 0:
        print(index, row[0])
    else:
        continue
# Out:
# MSZoning 4
# LotFrontage 227
# Utilities 2
# Exterior1st 1
# Exterior2nd 1
# MasVnrType 16
# MasVnrArea 15
# BsmtFinSF1 1
# BsmtFinSF2 1
# BsmtUnfSF 1
# TotalBsmtSF 1
# BsmtFullBath 2
# BsmtHalfBath 2
# KitchenQual 1
# Functional 2
# GarageYrBlt 78
# GarageCars 1
# GarageArea 1
# SaleType 1

# %%
def remove_outliers_and_get_skewness(df, column_name):
    Q1 = df[column_name].quantile(0.25)
    Q3 = df[column_name].quantile(0.75)
    IQR = Q3 - Q1

    # Define the outlier condition
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Remove the outliers
    filtered_data = df[(df[column_name] >= lower_bound) & (df[column_name] <= upper_bound)]

    # Calculate skewness
    column_skewness = skew(filtered_data[column_name], bias=False)

    return column_skewness
def count_outliers(df, column_name):
    Q1 = df[column_name].quantile(0.25)
    Q3 = df[column_name].quantile(0.75)
    print(Q1)
    print(Q3)
    IQR = Q3 - Q1

    # Define the outlier condition
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    print(f"""Lower bound: {lower_bound}""")
    print(f"""Upper bound: {upper_bound}""")

    # Identify the outliers
    outliers = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

    # Return the number of outliers
    return len(outliers)

# %%
plt.figure(figsize=(10, 6))
sns.histplot(training['LotFrontage'], kde=True, bins=30)
plt.title(f'Distribution of LotFrontage')
plt.xlabel('LotFrontage')
plt.ylabel('Frequency')
plt.show()

# Calculate and print skewness
feature_skewness = skew(training['LotFrontage'].dropna())  # dropna() to ignore missing values
print(f'Skewness of LotFrontage before Imputing: {feature_skewness}')
skewness=remove_outliers_and_get_skewness(training,'LotFrontage')
print(f'Skewness of LotFrontage after removing outliers: {skewness}')
num_outliers = count_outliers(training, 'LotFrontage')
print(f'Number of outliers in LotFrontage: {num_outliers}')
# Out:
# Skewness of LotFrontage before Imputing: 2.1192880130649305
# Skewness of LotFrontage after removing outliers: 0.1712546200253359
# 58.52816681383371
# 80.0
# Lower bound: 26.320417034584267
# Upper bound: 112.20774977924944
# Number of outliers in LotFrontage: 139

# %%
sns.boxplot(data=training, x='LotFrontage')

# Add labels and a title
plt.xlabel('LotFrontage')
plt.title('Boxplot of LotFrontage')

# Show the plot
plt.show()

# %%
training['LotFrontage_original']=training['LotFrontage']
training['MasVnrArea_original']=training['MasVnrArea']

# %%
from eda_imputation import fill_missing_values
training,validation,test_data=fill_missing_values(training,test_data,validation)

# %%
nulls = training.isnull().sum().to_frame()
for index, row in nulls.iterrows():
    if (row[0] > 0) and not (index.endswith('_original')):
        print(index, row[0])
    else:
        continue

# %%
nulls = validation.isnull().sum().to_frame()
for index, row in nulls.iterrows():
    if row[0] > 0:
        print(index, row[0])
    else:
        continue

# %%
nulls = test_data.isnull().sum().to_frame()
for index, row in nulls.iterrows():
    if row[0] > 0:
        print(index, row[0])
    else:
        continue

# %%
training.to_csv('training_filled.csv',index=False)
validation.to_csv('validation_filled.csv',index=False)
test_data.to_csv('test_filled.csv',index=False)

# %%
plt.figure(figsize=(10, 6))

# Plot original data
sns.kdeplot(training['LotFrontage_original'], label='Before Imputation', color='blue', shade=True)

# Plot imputed data
sns.kdeplot(training['LotFrontage'], label='After Imputation', color='red', shade=True)

# Add labels and title
plt.title('Distribution Comparison: Before and After Imputation')
plt.xlabel('LotFrontage')
plt.ylabel('Density')

# Show legend
plt.legend()

# Show plot
plt.show()
feature_skewness = skew(training['LotFrontage'].dropna())  # dropna() to ignore missing values
print(f'Skewness of LotFrontage after Imputing: {feature_skewness}')
skewness=remove_outliers_and_get_skewness(training,'LotFrontage')
print(f'Skewness of LotFrontage after removing outliers: {skewness}')
num_outliers = count_outliers(training, 'LotFrontage')
print(f'Number of outliers in LotFrontage: {num_outliers}')
# Out:
# Skewness of LotFrontage after Imputing: 1.8983210666926353
# Skewness of LotFrontage after removing outliers: 0.0645569241268193
# 59.679893703359994
# 80.07691898169632
# Lower bound: 29.0843557858555
# Upper bound: 110.67245689920082
# Number of outliers in LotFrontage: 154

# %%
plt.figure(figsize=(10, 6))

# Plot original data
sns.kdeplot(training['MasVnrArea_original'], label='Before Imputation', color='blue', shade=True)

# Plot imputed data
sns.kdeplot(training['MasVnrArea'], label='After Imputation', color='red', shade=True)

# Add labels and title
plt.title('Distribution Comparison: Before and After Imputation')
plt.xlabel('MasVnrArea')
plt.ylabel('Density')

# Show legend
plt.legend()

# Show plot
plt.show()
feature_skewness = skew(training['MasVnrArea'].dropna())  # dropna() to ignore missing values
print(f'Skewness of LotFrontage after Imputing: {feature_skewness}')
skewness=remove_outliers_and_get_skewness(training,'MasVnrArea')
print(f'Skewness of LotFrontage after removing outliers: {skewness}')
num_outliers = count_outliers(training, 'MasVnrArea')
print(f'Number of outliers in LotFrontage: {num_outliers}')
# Out:
# Skewness of LotFrontage after Imputing: 2.588687459885967
# Skewness of LotFrontage after removing outliers: 1.4619766909101837
# 0.0
# 155.51868209113152
# Lower bound: -233.2780231366973
# Upper bound: 388.79670522782885
# Number of outliers in LotFrontage: 149

# %%
plt.scatter(np.sqrt(training['LotArea']), training['LotFrontage'], label='After Imputation', alpha=0.5)
plt.scatter(np.sqrt(training['LotArea']), training['LotFrontage_original'], label='Before Imputation', alpha=0.5)
plt.xlabel('sqrt(LotArea)')
plt.ylabel('LotFrontage')
plt.legend()
plt.title("Scatter Plot of LotFrontage vs sqrt(LotArea)")
plt.show()

# %%
training.drop(columns=[col for col in training.columns if col.endswith('_original')], inplace=True)
training
# Out:
#           Id  MSSubClass MSZoning  LotFrontage       LotArea Street Alley  \
# 0      640_2         120       RL    53.314808   3958.064069   Pave    NA
# 1      151_1          20       RL   120.168346  10277.720194   Pave    NA
# 2        870          60       RL    80.000000   9938.000000   Pave    NA
# 3        8_1          60       RL    94.000000  10372.811187   Pave    NA
# 4     1113_1          20       RL    72.757550   7049.580102   Pave    NA
# ...      ...         ...      ...          ...           ...    ...   ...
# 2331   973_1         120       RL    55.147984   7899.828740   Pave    NA
# 2332    1096          20       RL    78.000000   9317.000000   Pave    NA
# 2333    1131          50       RL    65.000000   7804.000000   Pave    NA
# 2334    1295          20       RL    60.000000   8172.000000   Pave    NA
# 2335     861          50       RL    55.000000   7642.000000   Pave    NA
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# 0         Reg         Lvl    AllPub  ...        0     NA     NA          NA
# 1         Reg         Lvl    AllPub  ...        0     NA  MnPrv          NA
# 2         Reg         Lvl    AllPub  ...        0     NA  GdPrv          NA
# 3         IR1         Lvl    AllPub  ...        0     NA     NA        Shed
# 4         IR1         Lvl    AllPub  ...        0     NA     NA          NA
# ...       ...         ...       ...  ...      ...    ...    ...         ...
# 2331      Reg         Lvl    AllPub  ...        0     NA     NA          NA
# 2332      IR1         Lvl    AllPub  ...        0     NA     NA          NA
# 2333      Reg         Lvl    AllPub  ...        0     NA  MnPrv          NA
# 2334      Reg         Lvl    AllPub  ...        0     NA     NA          NA
# 2335      Reg         Lvl    AllPub  ...        0     NA  GdPrv          NA
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition      SalePrice
# 0          0     10   2006       New        Partial  265697.251067
# 1          0      1   2007        WD         Normal  121079.608459
# 2          0      6   2010        WD         Normal  236000.000000
# 3        350     11   2009        WD         Normal  199711.285054
# 4          0      7   2006        WD         Normal  130130.427995
# ...      ...    ...    ...       ...            ...            ...
# 2331       0      4   2010        WD         Normal   99067.134982
# 2332       0      3   2007        WD         Normal  176432.000000
# 2333       0     12   2009        WD         Normal  135000.000000
# 2334       0      4   2006        WD         Normal  115000.000000
# 2335       0      6   2007        WD         Normal  189950.000000
#
# [2336 rows x 81 columns]

# %% [markdown]
# # Analysis and Transformations to the Response Variable

# %%
plt.figure(figsize=(10, 6))
sns.histplot(training['SalePrice'], kde=True, bins=30)
plt.title(f'Distribution of SalePrice')
plt.xlabel('SalePrice')
plt.ylabel('Frequency')
plt.show()

# Calculate and print skewness
feature_skewness = skew(training['SalePrice'].dropna())  # dropna() to ignore missing values
print(f'Skewness of SalePrice: {feature_skewness}')
print(f"Kurtosis: {training['SalePrice'].kurtosis():.4f}")
num_outliers = count_outliers(training, 'SalePrice')
print(f'Number of outliers in LotFrontage: {num_outliers}')
# Out:
# Skewness of SalePrice: 1.8374030892828799
# Kurtosis: 6.0404
# 129619.62001579569
# 211722.6651575156
# Lower bound: 6465.052303215809
# Upper bound: 334877.2328700955
# Number of outliers in LotFrontage: 109

# %%
from scipy.stats.mstats import winsorize
training['SalePrice']=np.log(training['SalePrice']/100000)
validation['SalePrice']=np.log(validation['SalePrice']/100000)
plt.figure(figsize=(10, 6))
sns.histplot(training['SalePrice'], kde=True, bins=30)
plt.title(f'Distribution of Transformed SalePrice')
plt.xlabel('SalePrice')
plt.ylabel('Frequency')
plt.show()

# Calculate and print skewness
feature_skewness = skew(training['SalePrice'].dropna())  # dropna() to ignore missing values
print(f'Skewness of SalePrice after transformation: {feature_skewness}')
print(f"Kurtosis after transformation: {training['SalePrice'].kurtosis():.4f}")
num_outliers = count_outliers(training, 'SalePrice')
print(f'Number of outliers in SalePrice: {num_outliers}')
# Out:
# Skewness of SalePrice after transformation: 0.273737416165819
# Kurtosis after transformation: 0.5071
# 0.2594338334811016
# 0.7501070490292878
# Lower bound: -0.47657598984117777
# Upper bound: 1.4861168723515672
# Number of outliers in SalePrice: 29

# %%
import scipy.stats as stats
# Q-Q Plot
stats.probplot(training["SalePrice"], dist="norm", plot=plt)
plt.title("Q-Q Plot of Log1p(SalePrice)")
plt.show()

# %% [markdown]
# # Feature Engineering
