# %%
#Imported Packages:

#Generic
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

#Data Modeling
from sklearn.model_selection import train_test_split
from sklearn import metrics

#Data Visualization
from scipy.stats import iqr
from scipy.stats import skew
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_data=pd.read_csv('train.csv',keep_default_na=False,na_values=[" ", "#N/A", "#N/A N/A", "#NA", "-1.#IND", "-1.#QNAN", "-NaN", "-nan", "1.#IND", "1.#QNAN", "<NA>", "N/A", "NULL", "NaN", "n/a", "nan", "null","NA"])
test_data=pd.read_csv('test.csv',keep_default_na=False,na_values=[" ", "#N/A", "#N/A N/A", "#NA", "-1.#IND", "-1.#QNAN", "-NaN", "-nan", "1.#IND", "1.#QNAN", "<NA>", "N/A", "NULL", "NaN", "n/a", "nan", "null","NA"])
default_NA={'Alley':'NA','BsmtQual':'NA','BsmtCond':'NA','BsmtExposure':'NA',
            'BsmtFinType1':'NA','BsmtFinType2':'NA','FireplaceQu':'NA',
            'GarageType':'NA','GarageFinish':'NA',
            'GarageQual':'NA','GarageCond':'NA','PoolQC':'NA','Fence':'NA','MiscFeature':'NA'}
train_data=train_data.fillna(default_NA)
test_data=test_data.fillna(default_NA)

# %%
nulls = train_data.isnull().sum().to_frame()
for index, row in nulls.iterrows():
    if row[0] > 0:
        print(index, row[0]/len(train_data))
    else:
        continue
# Out:
# LotFrontage 0.1773972602739726
# MasVnrType 0.005479452054794521
# MasVnrArea 0.005479452054794521
# Electrical 0.0006849315068493151
# GarageYrBlt 0.05547945205479452

# %%
nulls = test_data.isnull().sum().to_frame()
for index, row in nulls.iterrows():
    if row[0] > 0:
        print(index, row[0])
    else:
        continue
# Out:
# MSZoning 4
# LotFrontage 227
# Utilities 2
# Exterior1st 1
# Exterior2nd 1
# MasVnrType 16
# MasVnrArea 15
# BsmtFinSF1 1
# BsmtFinSF2 1
# BsmtUnfSF 1
# TotalBsmtSF 1
# BsmtFullBath 2
# BsmtHalfBath 2
# KitchenQual 1
# Functional 2
# GarageYrBlt 78
# GarageCars 1
# GarageArea 1
# SaleType 1

# %%
def remove_outliers_and_get_skewness(df, column_name):
    Q1 = df[column_name].quantile(0.25)
    Q3 = df[column_name].quantile(0.75)
    IQR = Q3 - Q1

    # Define the outlier condition
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Remove the outliers
    filtered_data = df[(df[column_name] >= lower_bound) & (df[column_name] <= upper_bound)]

    # Calculate skewness
    column_skewness = skew(filtered_data[column_name], bias=False)

    return column_skewness
def count_outliers(df, column_name):
    Q1 = df[column_name].quantile(0.25)
    Q3 = df[column_name].quantile(0.75)
    print(Q1)
    print(Q3)
    IQR = Q3 - Q1

    # Define the outlier condition
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    print(lower_bound)
    print(upper_bound)

    # Identify the outliers
    outliers = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

    # Return the number of outliers
    return len(outliers)

# %%
X_train,X_valid,y_train,y_valid=train_test_split(train_data.loc[:,train_data.columns!='SalesPrice'],train_data.loc[:,train_data.columns=='SalesPrice'],test_size=0.2,random_state=42)
training = X_train.join(y_train)
validation = X_valid.join(y_valid)
X_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 254    255          20       RL         70.0     8400   Pave    NA      Reg
# 1066  1067          60       RL         59.0     7837   Pave    NA      IR1
# 638    639          30       RL         67.0     8777   Pave    NA      Reg
# 799    800          50       RL         60.0     7200   Pave    NA      Reg
# 380    381          50       RL         50.0     5000   Pave  Pave      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1095  1096          20       RL         78.0     9317   Pave    NA      IR1
# 1130  1131          50       RL         65.0     7804   Pave    NA      Reg
# 1294  1295          20       RL         60.0     8172   Pave    NA      Reg
# 860    861          50       RL         55.0     7642   Pave    NA      Reg
# 1126  1127         120       RL         53.0     3684   Pave    NA      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 254          Lvl    AllPub  ...        0     NA     NA          NA       0
# 1066         Lvl    AllPub  ...        0     NA     NA          NA       0
# 638          Lvl    AllPub  ...        0     NA  MnPrv          NA       0
# 799          Lvl    AllPub  ...        0     NA  MnPrv          NA       0
# 380          Lvl    AllPub  ...        0     NA     NA          NA       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1095         Lvl    AllPub  ...        0     NA     NA          NA       0
# 1130         Lvl    AllPub  ...        0     NA  MnPrv          NA       0
# 1294         Lvl    AllPub  ...        0     NA     NA          NA       0
# 860          Lvl    AllPub  ...        0     NA  GdPrv          NA       0
# 1126         Lvl    AllPub  ...        0     NA     NA          NA       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 254       6   2010        WD         Normal     145000
# 1066      5   2009        WD         Normal     178000
# 638       5   2008        WD         Normal      85000
# 799       6   2007        WD         Normal     175000
# 380       5   2010        WD         Normal     127000
# ...     ...    ...       ...            ...        ...
# 1095      3   2007        WD         Normal     176432
# 1130     12   2009        WD         Normal     135000
# 1294      4   2006        WD         Normal     115000
# 860       6   2007        WD         Normal     189950
# 1126      6   2009        WD         Normal     174000
#
# [1168 rows x 81 columns]

# %%
training.to_csv('training.csv',index=False)
validation.to_csv('validation.csv',index=False)

# %%
nulls = training.isnull().sum().to_frame()
for index, row in nulls.iterrows():
    if row[0] > 0:
        print(index, row[0])
    else:
        continue
# Out:
# LotFrontage 217
# MasVnrType 6
# MasVnrArea 6
# Electrical 1
# GarageYrBlt 64

# %%
nulls = validation.isnull().sum().to_frame()
for index, row in nulls.iterrows():
    if row[0] > 0:
        print(index, row[0])
    else:
        continue
# Out:
# LotFrontage 42
# MasVnrType 2
# MasVnrArea 2
# GarageYrBlt 17

# %%
nulls = test_data.isnull().sum().to_frame()
for index, row in nulls.iterrows():
    if row[0] > 0:
        print(index, row[0])
    else:
        continue
# Out:
# MSZoning 4
# LotFrontage 227
# Utilities 2
# Exterior1st 1
# Exterior2nd 1
# MasVnrType 16
# MasVnrArea 15
# BsmtFinSF1 1
# BsmtFinSF2 1
# BsmtUnfSF 1
# TotalBsmtSF 1
# BsmtFullBath 2
# BsmtHalfBath 2
# KitchenQual 1
# Functional 2
# GarageYrBlt 78
# GarageCars 1
# GarageArea 1
# SaleType 1

# %%
plt.figure(figsize=(10, 6))
sns.histplot(training['LotFrontage'], kde=True, bins=30)
plt.title(f'Distribution of LotFrontage')
plt.xlabel('LotFrontage')
plt.ylabel('Frequency')
plt.show()

# Calculate and print skewness
feature_skewness = skew(training['LotFrontage'].dropna())  # dropna() to ignore missing values
print(f'Skewness of LotFrontage before Imputing: {feature_skewness}')
skewness=remove_outliers_and_get_skewness(training,'LotFrontage')
print(f'Skewness of LotFrontage after removing outliers: {skewness}')
num_outliers = count_outliers(training, 'LotFrontage')
print(f'Number of outliers in LotFrontage: {num_outliers}')
# Out:
# Skewness of LotFrontage before Imputing: 2.402989168767883
# Skewness of LotFrontage after removing outliers: 0.0901739181888894
# 59.0
# 80.0
# 27.5
# 111.5
# Number of outliers in LotFrontage: 68

# %%
sns.boxplot(data=training, x='LotFrontage')

# Add labels and a title
plt.xlabel('LotFrontage')
plt.title('Boxplot of LotFrontage')

# Show the plot
plt.show()

# %%
training['LotFrontage_original']=training['LotFrontage']
training['MasVnrArea_original']=training['MasVnrArea']

# %%
from eda_imputation import fill_missing_values
training,validation,test_data=fill_missing_values(training,test_data,validation)

# %%
nulls = training.isnull().sum().to_frame()
for index, row in nulls.iterrows():
    if (row[0] > 0) and not (index.endswith('_original')):
        print(index, row[0])
    else:
        continue

# %%
nulls = validation.isnull().sum().to_frame()
for index, row in nulls.iterrows():
    if row[0] > 0:
        print(index, row[0])
    else:
        continue

# %%
nulls = test_data.isnull().sum().to_frame()
for index, row in nulls.iterrows():
    if row[0] > 0:
        print(index, row[0])
    else:
        continue

# %%
training.to_csv('training_filled.csv',index=False)
validation.to_csv('validation_filled.csv',index=False)
test_data.to_csv('test_filled.csv',index=False)

# %%
plt.figure(figsize=(10, 6))

# Plot original data
sns.kdeplot(training['LotFrontage_original'], label='Before Imputation', color='blue', shade=True)

# Plot imputed data
sns.kdeplot(training['LotFrontage'], label='After Imputation', color='red', shade=True)

# Add labels and title
plt.title('Distribution Comparison: Before and After Imputation')
plt.xlabel('LotFrontage')
plt.ylabel('Density')

# Show legend
plt.legend()

# Show plot
plt.show()
feature_skewness = skew(training['LotFrontage'].dropna())  # dropna() to ignore missing values
print(f'Skewness of LotFrontage after Imputing: {feature_skewness}')
skewness=remove_outliers_and_get_skewness(training,'LotFrontage')
print(f'Skewness of LotFrontage after removing outliers: {skewness}')
num_outliers = count_outliers(training, 'LotFrontage')
print(f'Number of outliers in LotFrontage: {num_outliers}')
# Out:
# Skewness of LotFrontage after Imputing: 2.280509477520938
# Skewness of LotFrontage after removing outliers: 0.013802165059614797
# 60.0
# 80.0
# 30.0
# 110.0
# Number of outliers in LotFrontage: 73

# %%
plt.figure(figsize=(10, 6))

# Plot original data
sns.kdeplot(training['MasVnrArea_original'], label='Before Imputation', color='blue', shade=True)

# Plot imputed data
sns.kdeplot(training['MasVnrArea'], label='After Imputation', color='red', shade=True)

# Add labels and title
plt.title('Distribution Comparison: Before and After Imputation')
plt.xlabel('MasVnrArea')
plt.ylabel('Density')

# Show legend
plt.legend()

# Show plot
plt.show()
feature_skewness = skew(training['MasVnrArea'].dropna())  # dropna() to ignore missing values
print(f'Skewness of LotFrontage after Imputing: {feature_skewness}')
skewness=remove_outliers_and_get_skewness(training,'MasVnrArea')
print(f'Skewness of LotFrontage after removing outliers: {skewness}')
num_outliers = count_outliers(training, 'MasVnrArea')
print(f'Number of outliers in LotFrontage: {num_outliers}')
# Out:
# Skewness of LotFrontage after Imputing: 2.289205682330244
# Skewness of LotFrontage after removing outliers: 1.4117426386197205
# 0.0
# 166.0
# -249.0
# 415.0
# Number of outliers in LotFrontage: 77

# %%
plt.scatter(np.sqrt(training['LotArea']), training['LotFrontage'], label='After Imputation', alpha=0.5)
plt.scatter(np.sqrt(training['LotArea']), training['LotFrontage_original'], label='Before Imputation', alpha=0.5)
plt.xlabel('sqrt(LotArea)')
plt.ylabel('LotFrontage')
plt.legend()
plt.title("Scatter Plot of LotFrontage vs sqrt(LotArea)")
plt.show()

# %%
training.drop(columns=[col for col in training.columns if col.endswith('_original')], inplace=True)
training
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0      255          20       RL         70.0     8400   Pave    NA      Reg
# 1     1067          60       RL         59.0     7837   Pave    NA      IR1
# 2      639          30       RL         67.0     8777   Pave    NA      Reg
# 3      800          50       RL         60.0     7200   Pave    NA      Reg
# 4      381          50       RL         50.0     5000   Pave  Pave      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1163  1096          20       RL         78.0     9317   Pave    NA      IR1
# 1164  1131          50       RL         65.0     7804   Pave    NA      Reg
# 1165  1295          20       RL         60.0     8172   Pave    NA      Reg
# 1166   861          50       RL         55.0     7642   Pave    NA      Reg
# 1167  1127         120       RL         53.0     3684   Pave    NA      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0     NA     NA          NA       0
# 1            Lvl    AllPub  ...        0     NA     NA          NA       0
# 2            Lvl    AllPub  ...        0     NA  MnPrv          NA       0
# 3            Lvl    AllPub  ...        0     NA  MnPrv          NA       0
# 4            Lvl    AllPub  ...        0     NA     NA          NA       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1163         Lvl    AllPub  ...        0     NA     NA          NA       0
# 1164         Lvl    AllPub  ...        0     NA  MnPrv          NA       0
# 1165         Lvl    AllPub  ...        0     NA     NA          NA       0
# 1166         Lvl    AllPub  ...        0     NA  GdPrv          NA       0
# 1167         Lvl    AllPub  ...        0     NA     NA          NA       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         6   2010        WD         Normal     145000
# 1         5   2009        WD         Normal     178000
# 2         5   2008        WD         Normal      85000
# 3         6   2007        WD         Normal     175000
# 4         5   2010        WD         Normal     127000
# ...     ...    ...       ...            ...        ...
# 1163      3   2007        WD         Normal     176432
# 1164     12   2009        WD         Normal     135000
# 1165      4   2006        WD         Normal     115000
# 1166      6   2007        WD         Normal     189950
# 1167      6   2009        WD         Normal     174000
#
# [1168 rows x 81 columns]

# %% [markdown]
# # Analysis and Transformations to the Response Variable

# %%
plt.figure(figsize=(10, 6))
sns.histplot(training['SalePrice'], kde=True, bins=30)
plt.title(f'Distribution of SalePrice')
plt.xlabel('SalePrice')
plt.ylabel('Frequency')
plt.show()

# Calculate and print skewness
feature_skewness = skew(training['SalePrice'].dropna())  # dropna() to ignore missing values
print(f'Skewness of SalePrice: {feature_skewness}')
# Out:
# Skewness of SalePrice: 1.7408891554667465

# %%
training['SalePrice']=np.log(training['SalePrice']/100000)
validation['SalePrice']=np.log(validation['SalePrice']/100000)
plt.figure(figsize=(10, 6))
sns.histplot(training['SalePrice'], kde=True, bins=30)
plt.title(f'Distribution of Transformed SalePrice')
plt.xlabel('SalePrice')
plt.ylabel('Frequency')
plt.show()

# Calculate and print skewness
feature_skewness = skew(training['SalePrice'].dropna())  # dropna() to ignore missing values
print(f'Skewness of SalePrice after transformation: {feature_skewness}')
# Out:
# Skewness of SalePrice after transformation: 0.12471907609541613

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ### Create New Features

# %%
training['Total_Bathrooms'] = (training['FullBath'] + (0.5 * training['HalfBath']) +
                               training['BsmtFullBath'] + (0.5 * training['BsmtHalfBath']))
validation['Total_Bathrooms'] = (validation['FullBath'] + (0.5 * validation['HalfBath']) +
                               validation['BsmtFullBath'] + (0.5 * validation['BsmtHalfBath']))
test_data['Total_Bathrooms'] = (test_data['FullBath'] + (0.5 *test_data['HalfBath']) +
                               test_data['BsmtFullBath'] + (0.5 * test_data['BsmtHalfBath']))

# %%
training['HomeAgeAtSale'] = training['YrSold'] - training['YearBuilt']
validation['HomeAgeAtSale'] = validation['YrSold'] - validation['YearBuilt']
test_data['HomeAgeAtSale'] = test_data['YrSold'] - test_data['YearBuilt']

# %%
training['GarageAge'] = training.apply(
    lambda row: row['YrSold'] - row['GarageYrBlt'] if row['GarageYrBlt'] != 0 else 0,
    axis=1
)
validation['GarageAge'] = validation.apply(
    lambda row: row['YrSold'] - row['GarageYrBlt'] if row['GarageYrBlt'] != 0 else 0,
    axis=1
)
test_data['GarageAge'] = test_data.apply(
    lambda row: row['YrSold'] - row['GarageYrBlt'] if row['GarageYrBlt'] != 0 else 0,
    axis=1
)
plt.figure(figsize=(10, 6))
sns.histplot(training['GarageAge'], kde=True, bins=30)
plt.title(f'Distribution of Transformed GarageAge')
plt.xlabel('GarageAge')
plt.ylabel('Frequency')
plt.show()

# Calculate and print skewness
feature_skewness = skew(training['GarageAge'].dropna())  # dropna() to ignore missing values
print(f'Skewness of GarageAge after transformation: {feature_skewness}')
# Out:
# Skewness of GarageAge after transformation: 0.7107487594888813

# %%
training['has_garage']=np.where(training['GarageYrBlt']==0,0,1)
validation['has_garage']=np.where(validation['GarageYrBlt']==0,0,1)
test_data['has_garage']=np.where(test_data['GarageYrBlt']==0,0,1)

# %%
training['CenturyBuilt'] = training['YearBuilt'].apply(lambda x: 1 if x < 2000 else 0)
validation['CenturyBuilt'] = validation['YearBuilt'].apply(lambda x: 1 if x < 2000 else 0)
test_data['CenturyBuilt'] = test_data['YearBuilt'].apply(lambda x: 1 if x < 2000 else 0)

# %%
training['Remodeled'] = (training['YearRemodAdd'] > training['YearBuilt']).astype(int)
validation['Remodeled'] = (validation['YearRemodAdd'] > validation['YearBuilt']).astype(int)
test_data['Remodeled'] = (test_data['YearRemodAdd'] > test_data['YearBuilt']).astype(int)

# %%
training['remodel_time'] = training['YrSold'] - training['YearRemodAdd']
validation['remodel_time'] = validation['YrSold'] - validation['YearRemodAdd']
test_data['remodel_time'] = test_data['YrSold'] - test_data['YearRemodAdd']

# %%
training['1stFlr_vs_2ndFlr'] = training['1stFlrSF'] - training['2ndFlrSF']
validation['1stFlr_vs_2ndFlr'] = validation['1stFlrSF'] - validation['2ndFlrSF']
test_data['1stFlr_vs_2ndFlr'] = test_data['1stFlrSF'] - test_data['2ndFlrSF']
plt.figure(figsize=(10, 6))
sns.histplot(training['1stFlr_vs_2ndFlr'], kde=True, bins=30)
plt.title(f'Distribution of Transformed 1stFlr_vs_2ndFlr')
plt.xlabel('1stFlr_vs_2ndFlr')
plt.ylabel('Frequency')
plt.show()

# Calculate and print skewness
feature_skewness = skew(training['1stFlr_vs_2ndFlr'].dropna())  # dropna() to ignore missing values
print(f'Skewness of 1stFlr_vs_2ndFlr after transformation: {feature_skewness}')
# Out:
# Skewness of 1stFlr_vs_2ndFlr after transformation: 0.16847856453249013

# %%
training['TotalPorchArea'] = training[['WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch']].sum(axis=1)
validation['TotalPorchArea'] = validation[['WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch']].sum(axis=1)
test_data['TotalPorchArea'] = test_data[['WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch']].sum(axis=1)
training['TotalPorchArea']=np.sqrt(training['TotalPorchArea'])
validation['TotalPorchArea']=np.sqrt(validation['TotalPorchArea'])
test_data['TotalPorchArea']=np.sqrt(test_data['TotalPorchArea'])
plt.figure(figsize=(10, 6))
sns.histplot(training['TotalPorchArea'], kde=True, bins=30)
plt.title(f'Distribution of Transformed TotalPorchArea')
plt.xlabel('TotalPorchArea')
plt.ylabel('Frequency')
plt.show()

# Calculate and print skewness
feature_skewness = skew(training['TotalPorchArea'].dropna())  # dropna() to ignore missing values
print(f'Skewness of TotalPorchArea after transformation: {feature_skewness}')
# Out:
# Skewness of TotalPorchArea after transformation: -0.27457879164283333

# %% [markdown]
# ### Reorganize Nominal Categories

# %%
import json
with open("nc_mapping.json", "r") as json_file:
    nc_mapping = json.load(json_file)
nc_mapping['MSSubClass'] = {int(k): v for k, v in nc_mapping['MSSubClass'].items()}
print(nc_mapping['MSSubClass'])
for key in nc_mapping:
    if key in training.columns:
        training[key] = training[key].map(nc_mapping[key]).fillna('Other')
        validation[key] = validation[key].map(nc_mapping[key]).fillna('Other')
        test_data[key] = test_data[key].map(nc_mapping[key]).fillna('Other')
# Out:
# {20: '1-Story', 30: '1-Story', 40: '1-Story', 45: '1-1/2 Story', 50: '1-1/2 Story', 60: '2-Story', 70: '2-Story', 75: '2-1/2 Story', 80: 'Multi-Level', 85: 'Multi-Level', 90: 'Other', 120: 'PUD', 150: 'PUD', 160: 'PUD', 180: 'Multi-Level', 190: 'Other'}

# %% [markdown]
# ### Transform Features

# %%
training['LotFrontage']=np.sqrt(training['LotFrontage'])
validation['LotFrontage']=np.sqrt(validation['LotFrontage'])
test_data['LotFrontage']=np.sqrt(test_data['LotFrontage'])
plt.figure(figsize=(10, 6))
sns.histplot(training['LotFrontage'], kde=True, bins=30)
plt.title(f'Distribution of Transformed LotFrontage')
plt.xlabel('LotFrontage')
plt.ylabel('Frequency')
plt.show()

# Calculate and print skewness
feature_skewness = skew(training['LotFrontage'].dropna())  # dropna() to ignore missing values
print(f'Skewness of LotFrontage after transformation: {feature_skewness}')
# Out:
# Skewness of LotFrontage after transformation: 0.39519754214786595

# %%
training['LotArea']=np.log1p(training['LotArea'])
validation['LotArea']=np.log1p(validation['LotArea'])
test_data['LotArea']=np.log1p(test_data['LotArea'])
plt.figure(figsize=(10, 6))
sns.histplot(training['LotArea'], kde=True, bins=30)
plt.title(f'Distribution of Transformed LotArea')
plt.xlabel('LotArea')
plt.ylabel('Frequency')
plt.show()

# Calculate and print skewness
feature_skewness = skew(training['LotArea'].dropna())  # dropna() to ignore missing values
print(f'Skewness of LotArea after transformation: {feature_skewness}')
# Out:
# Skewness of LotArea after transformation: -0.012582741081723673

# %%
training['GrLivArea']=np.sqrt(training['GrLivArea'])
validation['GrLivArea']=np.sqrt(validation['GrLivArea'])
test_data['GrLivArea']=np.sqrt(test_data['GrLivArea'])
plt.figure(figsize=(10, 6))
sns.histplot(training['GrLivArea'], kde=True, bins=30)
plt.title(f'Distribution of Transformed GrLivArea')
plt.xlabel('GrLivArea')
plt.ylabel('Frequency')
plt.show()

# Calculate and print skewness
feature_skewness = skew(training['GrLivArea'].dropna())  # dropna() to ignore missing values
print(f'Skewness of GrLivArea after transformation: {feature_skewness}')
# Out:
# Skewness of GrLivArea after transformation: 0.6200627925636288

# %%
training['BsmtFinSF1']=np.log1p(training['BsmtFinSF1'])
validation['BsmtFinSF1']=np.log1p(validation['BsmtFinSF1'])
test_data['BsmtFinSF1']=np.log1p(test_data['BsmtFinSF1'])
plt.figure(figsize=(10, 6))
sns.histplot(training['BsmtFinSF1'], kde=True, bins=30)
plt.title(f'Distribution of Transformed BsmtFinSF1')
plt.xlabel('BsmtFinSF1')
plt.ylabel('Frequency')
plt.show()

# Calculate and print skewness
feature_skewness = skew(training['BsmtFinSF1'].dropna())  # dropna() to ignore missing values
print(f'Skewness of BsmtFinSF1 after transformation: {feature_skewness}')
# Out:
# Skewness of BsmtFinSF1 after transformation: -0.6218007257101116

# %%
def reposition_target_col(df,target_col):
    temp = df.pop(target_col)
    df[target_col] = temp
    return df
training=reposition_target_col(training,'SalePrice')
validation=reposition_target_col(validation,'SalePrice')

# %%
training.to_csv('training_reengineered.csv')

# %%
from eda_best_features import get_cat_feat,select_best_continuous_features
nc=['MSSubClass','MSZoning','Street','Alley','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood','Condition1','Condition2','BldgType','HouseStyle','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','Foundation','Heating','CentralAir','Electrical','GarageType','MiscFeature','SaleType','SaleCondition']
nc_derived=['has_garage','CenturyBuilt','Remodeled']
nc_full=nc+nc_derived
oc=['OverallQual','OverallCond','ExterQual','ExterCond','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','HeatingQC','KitchenQual','Functional','FireplaceQu','GarageFinish','GarageQual','GarageCond','PavedDrive','PoolQC','Fence']
oc_derived=[]
oc_full=oc+oc_derived
num_feat=['LotFrontage','LotArea','YearBuilt', 'YearRemodAdd','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','LowQualFinSF','GrLivArea','BsmtFullBath','BsmtHalfBath','FullBath','HalfBath','BedroomAbvGr','KitchenAbvGr','TotRmsAbvGrd','GarageYrBlt','Fireplaces','GarageCars','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea','MiscVal','MoSold','YrSold']
num_feat_derived=['HomeAgeAtSale','GarageAge','TotalPorchArea','Total_Bathrooms','remodel_time','1stFlr_vs_2ndFlr']
num_feat_full=num_feat+num_feat_derived
print(len(num_feat_full))
print(len(nc_full+oc_full+num_feat_full))
target=['SalePrice']
best_cat=get_cat_feat(training[nc_full+oc_full+['SalePrice']],nc_full+oc_full,'SalePrice',0.05)
best_cat
# Out:
# 39
# 88
# ['MSSubClass',
#  'MSZoning',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'LotConfig',
#  'Neighborhood',
#  'Condition1',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'Foundation',
#  'Heating',
#  'CentralAir',
#  'Electrical',
#  'GarageType',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition',
#  'has_garage',
#  'CenturyBuilt',
#  'Remodeled',
#  'OverallQual',
#  'OverallCond',
#  'ExterQual',
#  'ExterCond',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'HeatingQC',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence']

# %%
stat_df,best_num=select_best_continuous_features(training[num_feat_full+target],num_feat_full,'SalePrice')
best_num
# Out:
# ['LotFrontage',
#  'LotArea',
#  'YearBuilt',
#  'YearRemodAdd',
#  'BsmtFinSF1',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'FullBath',
#  'TotRmsAbvGrd',
#  'GarageYrBlt',
#  'Fireplaces',
#  'GarageCars',
#  'GarageArea',
#  'OpenPorchSF',
#  'HomeAgeAtSale',
#  'GarageAge',
#  'TotalPorchArea',
#  'Total_Bathrooms',
#  'remodel_time',
#  '1stFlr_vs_2ndFlr']

# %%
training=training.loc[:,training.columns.isin(best_num+best_cat+['SalePrice'])]
validation=validation.loc[:,validation.columns.isin(best_num+best_cat+['SalePrice'])]
test_data=test_data.loc[:,test_data.columns.isin(best_num+best_cat)]
validation
# Out:
#       MSSubClass MSZoning  LotFrontage   LotArea Alley LotShape LandContour  \
# 0        1-Story       RL     8.366600  9.037771    NA      Reg         Lvl
# 1        2-Story       RL     9.899495  9.413852    NA      IR1         Lvl
# 2        1-Story       RM     7.483315  9.100637  Grvl      Reg         Lvl
# 3    1-1/2 Story       RM     7.071068  8.517393    NA      Reg         Lvl
# 4        1-Story       RL     9.433981  9.464905    NA      IR1         HLS
# ..           ...      ...          ...       ...   ...      ...         ...
# 287      1-Story       RM     7.071068  8.687105    NA      Reg         Bnk
# 288      1-Story       RL    11.135529  9.690232    NA      IR1         Low
# 289      2-Story       RL     7.937254  9.011889    NA      Reg         Lvl
# 290      2-Story       RL     7.745967  9.114380    NA      Reg         Lvl
# 291      1-Story       RL     8.366600  9.002209    NA      Reg         Lvl
#
#     LotConfig Neighborhood      Condition1  ... Total_Bathrooms HomeAgeAtSale  \
# 0      Inside       Sawyer  Road Proximity  ...             1.5            43
# 1      Corner      NoRidge  Road Proximity  ...             3.5            16
# 2      Inside      OldTown  Road Proximity  ...             1.0            83
# 3      Corner      BrkSide  Road Proximity  ...             2.0            59
# 4      Inside       Timber  Road Proximity  ...             3.0             2
# ..        ...          ...             ...  ...             ...           ...
# 287    Inside      OldTown  Road Proximity  ...             1.0            70
# 288    Inside      StoneBr  Road Proximity  ...             3.0             4
# 289    Inside      CollgCr  Road Proximity  ...             3.5             3
# 290    Inside      Edwards  Road Proximity  ...             2.0            69
# 291    Inside        NAmes  Road Proximity  ...             1.0            39
#
#      GarageAge  has_garage  CenturyBuilt  Remodeled remodel_time  \
# 0         43.0           1             1          1            3
# 1         16.0           1             1          1           15
# 2         83.0           1             1          1           60
# 3         56.0           1             1          1           56
# 4          1.0           1             0          1            1
# ..         ...         ...           ...        ...          ...
# 287       12.0           1             1          1            7
# 288        4.0           1             0          0            4
# 289        3.0           1             0          0            3
# 290       69.0           1             1          1           59
# 291       15.0           1             1          0           39
#
#     1stFlr_vs_2ndFlr TotalPorchArea SalePrice
# 0               1068      13.856406  0.435024
# 1                378      14.764823  1.178655
# 2               1028      11.401754  0.139762
# 3                344       7.745967  0.463734
# 4               1620      15.099669  1.148988
# ..               ...            ...       ...
# 287             1131       8.485281 -0.111256
# 288             1530      14.282857  0.955511
# 289                0       7.348469  0.636577
# 290                0      10.954451  0.076961
# 291              864       0.000000  0.219136
#
# [292 rows x 69 columns]

# %%
from eda_preprocesser import feature_encoder
mod_encoder=feature_encoder()
training=mod_encoder.fit_transform(training)
validation=mod_encoder.transform(validation)
test_data=mod_encoder.transform(test_data)

# %% [markdown]
# ### Scaling Continuous Features

# %%
from sklearn.preprocessing import StandardScaler,RobustScaler,QuantileTransformer
s_scaler = StandardScaler()
stand_feat=['LotArea','LotFrontage','TotalPorchArea','TotalBsmtSF','remodel_time']
training[stand_feat] = s_scaler.fit_transform(training[stand_feat])
validation[stand_feat] = s_scaler.transform(validation[stand_feat])
test_data[stand_feat] = s_scaler.transform(test_data[stand_feat])

# %%
plt.figure(figsize=(10, 6))
sns.histplot(training['TotalPorchArea'], kde=True, bins=30)
plt.title(f'Distribution of Transformed TotalPorchArea')
plt.xlabel('TotalPorchArea')
plt.ylabel('Frequency')
plt.show()

# Calculate and print skewness
feature_skewness = skew(training['TotalPorchArea'].dropna())  # dropna() to ignore missing values
print(f'Skewness of TotalPorchArea after transformation: {feature_skewness}')
# Out:
# Skewness of TotalPorchArea after transformation: -0.2745787916428334

# %%
from vif_mod import calculate_vif,vif_selection
vif_data=calculate_vif(training.loc[:,training.columns!='SalePrice'])
vif_data.to_csv('vif.csv')
vif_data
# Out:
#                   Feature       VIF
# 0           GarageType_NA       inf
# 1                2ndFlrSF       inf
# 2        1stFlr_vs_2ndFlr       inf
# 3            remodel_time       inf
# 4            YearRemodAdd       inf
# ..                    ...       ...
# 158        SaleType_ConLI  1.235508
# 159  Neighborhood_Blueste  1.228510
# 160          SaleType_Con  1.219589
# 161          SaleType_Oth  1.188718
# 162         LotConfig_FR3  1.133104
#
# [163 rows x 2 columns]

# %%
best_features=vif_data[vif_data['VIF']<10]['Feature'].values
best_features
# Out:
# array(['BldgType_Twnhs', 'Neighborhood_NWAmes', 'BsmtFinSF1',
#        'Exterior1st_Cement-based', 'Neighborhood_Gilbert',
#        'Neighborhood_Sawyer', 'Neighborhood_BrkSide', 'RoofStyle_Gambrel',
#        'Foundation_PConc', 'RoofMatl_Wood Roofing', 'GarageArea',
#        'GarageCars', 'HouseStyle_SFoyer', 'Neighborhood_NridgHt',
#        'MSZoning_RH', 'Neighborhood_Crawfor', 'Neighborhood_IDOTRR',
#        'Foundation_CBlock', 'MSSubClass_2-1/2 Story', 'BsmtFinType1',
#        'Neighborhood_SawyerW', 'Exterior1st_Other',
#        'Neighborhood_Mitchel', 'Exterior2nd_Shingles-based', 'BsmtQual',
#        'FireplaceQu', 'CenturyBuilt', 'Neighborhood_NoRidge',
#        'Fireplaces', 'SaleType_WD', 'RoofStyle_Mansard', 'TotRmsAbvGrd',
#        'Exterior1st_Shingles-based', 'OverallQual', 'HouseStyle_2.5Unf',
#        'Total_Bathrooms', 'LotArea', 'GarageType_Basment', 'FullBath',
#        'Neighborhood_Timber', 'Neighborhood_SWISU',
#        'Neighborhood_ClearCr', 'ExterQual', 'Neighborhood_BrDale',
#        'Foundation_Slab', 'BsmtCond', 'Neighborhood_MeadowV',
#        'SaleCondition_Normal', 'KitchenQual', 'HouseStyle_2.5Fin',
#        'LandContour_Lvl', 'LotFrontage', 'GarageFinish',
#        'Condition1_Railroad Proximity', 'Condition1_Road Proximity',
#        'RoofStyle_Shed', 'Neighborhood_StoneBr', 'GarageType_CarPort',
#        'MiscFeature_Othr', 'Alley_NA', 'Alley_Pave',
#        'RoofMatl_Specialty Roofing', 'CentralAir', 'OverallCond',
#        'HeatingQC', 'LandContour_Low', 'LandContour_HLS',
#        'Neighborhood_Veenker', 'Neighborhood_NPkVill',
#        'LotConfig_CulDSac', 'BsmtExposure', 'Exterior2nd_Stone-based',
#        'Remodeled', 'MiscFeature_TenC', 'TotalPorchArea', 'PavedDrive',
#        'LotConfig_Inside', 'Exterior1st_Stone-based', 'PoolQC',
#        'SaleType_ConLD', 'OpenPorchSF', 'Heating_Wall-Based',
#        'LotShape_Reg', 'Heating_Hot Water/Steam', 'SaleCondition_AdjLand',
#        'ExterCond', 'SaleCondition_Alloca', 'HouseStyle_1.5Unf',
#        'SaleCondition_Family', 'LotConfig_FR2', 'LotShape_IR3',
#        'Functional', 'BsmtFinType2', 'Heating_Gravity-Based', 'Fence',
#        'Foundation_Stone', 'LotShape_IR2', 'SaleType_ConLw',
#        'SaleType_CWD', 'Foundation_Wood', 'SaleType_ConLI',
#        'Neighborhood_Blueste', 'SaleType_Con', 'SaleType_Oth',
#        'LotConfig_FR3'], dtype=object)

# %%
redundancies=['YearBuilt','YearRemodAdd','GarageYrBlt','OpenPorchSF','BsmtUnfSF','2ndFlrSF','1stFlrSF']
filtered_columns=[col for col in training.columns if col not in redundancies+['SalePrice']]
vif_data=calculate_vif(training.loc[:,filtered_columns])
vif_data.to_csv('vif_2.csv')
vif_data
# Out:
#                   Feature          VIF
# 0              has_garage  3498.216643
# 1           GarageType_NA   173.040045
# 2         RoofStyle_Gable   156.472282
# 3           RoofStyle_Hip   145.619182
# 4            SaleType_New   122.013749
# ..                    ...          ...
# 151  Neighborhood_Blueste     1.227555
# 152        SaleType_ConLI     1.224165
# 153          SaleType_Con     1.216942
# 154          SaleType_Oth     1.182063
# 155         LotConfig_FR3     1.130355
#
# [156 rows x 2 columns]

# %%
best_features=vif_data[vif_data['VIF']<10]['Feature'].values
best_features
# Out:
# array(['BldgType_Twnhs', '1stFlr_vs_2ndFlr', 'Neighborhood_NWAmes',
#        'BsmtFinSF1', 'Exterior1st_Cement-based', 'Neighborhood_Gilbert',
#        'Neighborhood_Sawyer', 'RoofStyle_Gambrel', 'Neighborhood_BrkSide',
#        'RoofMatl_Wood Roofing', 'Foundation_PConc', 'GarageArea',
#        'GarageCars', 'Neighborhood_NridgHt', 'HouseStyle_SFoyer',
#        'Neighborhood_Crawfor', 'MSZoning_RH', 'Neighborhood_IDOTRR',
#        'Foundation_CBlock', 'MSSubClass_2-1/2 Story', 'BsmtFinType1',
#        'Neighborhood_SawyerW', 'Exterior1st_Other', 'GarageAge',
#        'Neighborhood_Mitchel', 'Exterior2nd_Shingles-based', 'BsmtQual',
#        'FireplaceQu', 'CenturyBuilt', 'Neighborhood_NoRidge',
#        'SaleType_WD', 'Fireplaces', 'TotRmsAbvGrd', 'RoofStyle_Mansard',
#        'OverallQual', 'Exterior1st_Shingles-based', 'LotArea',
#        'HouseStyle_2.5Unf', 'Total_Bathrooms', 'GarageType_Basment',
#        'TotalBsmtSF', 'FullBath', 'Neighborhood_Timber',
#        'Neighborhood_SWISU', 'Neighborhood_ClearCr', 'remodel_time',
#        'ExterQual', 'Neighborhood_BrDale', 'Foundation_Slab', 'BsmtCond',
#        'Neighborhood_MeadowV', 'SaleCondition_Normal', 'KitchenQual',
#        'HouseStyle_2.5Fin', 'LandContour_Lvl', 'LotFrontage',
#        'GarageFinish', 'Condition1_Railroad Proximity',
#        'Condition1_Road Proximity', 'RoofStyle_Shed',
#        'Neighborhood_StoneBr', 'GarageType_CarPort', 'Alley_NA',
#        'MiscFeature_Othr', 'Alley_Pave', 'RoofMatl_Specialty Roofing',
#        'CentralAir', 'HeatingQC', 'OverallCond', 'LandContour_Low',
#        'Neighborhood_Veenker', 'LandContour_HLS', 'Neighborhood_NPkVill',
#        'LotConfig_CulDSac', 'BsmtExposure', 'Exterior2nd_Stone-based',
#        'Remodeled', 'MiscFeature_TenC', 'PavedDrive', 'LotConfig_Inside',
#        'Exterior1st_Stone-based', 'SaleType_ConLD', 'Heating_Wall-Based',
#        'PoolQC', 'LotShape_Reg', 'Heating_Hot Water/Steam',
#        'TotalPorchArea', 'SaleCondition_AdjLand', 'ExterCond',
#        'SaleCondition_Alloca', 'HouseStyle_1.5Unf',
#        'SaleCondition_Family', 'LotConfig_FR2', 'LotShape_IR3',
#        'Functional', 'BsmtFinType2', 'Fence', 'Heating_Gravity-Based',
#        'Foundation_Stone', 'LotShape_IR2', 'SaleType_ConLw',
#        'SaleType_CWD', 'Foundation_Wood', 'Neighborhood_Blueste',
#        'SaleType_ConLI', 'SaleType_Con', 'SaleType_Oth', 'LotConfig_FR3'],
#       dtype=object)

# %%
vif_data,best_features_tem=vif_selection(training.loc[:,training.columns!='SalePrice'],10,redundancies)
vif_data.to_csv('vif_3.csv')
# Out:
# Dropped 'has_garage' with VIF: 3498.22
# Dropped 'RoofMatl_Standard Roofing' with VIF: 1011.14
# Dropped 'MiscFeature_NA' with VIF: 668.61
# Dropped 'Electrical_Romex_Wiring' with VIF: 532.17
# Dropped 'GrLivArea' with VIF: 430.37
# Dropped 'GarageCond' with VIF: 344.11
# Dropped 'MSZoning_RL' with VIF: 276.91
# Dropped 'GarageQual' with VIF: 186.66
# Dropped 'SaleType_New' with VIF: 132.27
# Dropped 'GarageType_Attchd' with VIF: 125.56
# Dropped 'RoofStyle_Gable' with VIF: 101.30
# Dropped 'OverallQual' with VIF: 99.69
# Dropped 'BsmtCond' with VIF: 97.38
# Dropped 'MSSubClass_Other' with VIF: 85.90
# Dropped 'Exterior2nd_Vinyl-based' with VIF: 77.91
# Dropped 'HouseStyle_1Story' with VIF: 71.24
# Dropped 'BsmtQual' with VIF: 69.01
# Dropped 'ExterQual' with VIF: 64.61
# Dropped 'TotRmsAbvGrd' with VIF: 59.73
# Dropped 'OverallCond' with VIF: 56.14
# Dropped 'Condition1_Road Proximity' with VIF: 55.34
# Dropped 'MasVnrType_None' with VIF: 54.80
# Dropped 'GarageCars' with VIF: 47.24
# Dropped 'ExterCond' with VIF: 45.35
# Dropped 'Total_Bathrooms' with VIF: 41.87
# Dropped 'KitchenQual' with VIF: 41.72
# Dropped 'Alley_NA' with VIF: 37.83
# Dropped 'SaleType_WD' with VIF: 35.63
# Dropped 'Exterior2nd_Metal-based' with VIF: 33.77
# Dropped 'MSSubClass_PUD' with VIF: 31.96
# Dropped 'LandContour_Lvl' with VIF: 31.69
# Dropped 'CentralAir' with VIF: 30.05
# Dropped 'HomeAgeAtSale' with VIF: 25.79
# Dropped 'BsmtFinSF1' with VIF: 24.15
# Dropped 'HeatingQC' with VIF: 23.68
# Dropped 'PavedDrive' with VIF: 22.62
# Dropped 'FullBath' with VIF: 21.66
# Dropped 'GarageArea' with VIF: 19.89
# Dropped '1stFlr_vs_2ndFlr' with VIF: 17.94
# Dropped 'CenturyBuilt' with VIF: 16.32
# Dropped 'Exterior1st_Vinyl-based' with VIF: 16.10
# Dropped 'SaleCondition_Normal' with VIF: 15.10
# Dropped 'MSSubClass_2-Story' with VIF: 13.96
# Dropped 'GarageFinish' with VIF: 12.41
# Dropped 'Exterior2nd_Wood-based' with VIF: 11.23
# Dropped 'Foundation_PConc' with VIF: 10.57
# Dropped 'FireplaceQu' with VIF: 10.23
# Dropped 'MSSubClass_Multi-Level' with VIF: 10.07

# %%
best_features_tem
# Out:
# array(['GarageAge', 'BsmtFinType1', 'Neighborhood_OldTown',
#        'Neighborhood_Somerst', 'Neighborhood_NAmes', 'BsmtExposure',
#        'MSSubClass_1-Story', 'Exterior2nd_Cement-based',
#        'Exterior1st_Cement-based', 'LotConfig_Inside', 'MSZoning_FV',
#        'MSZoning_RM', 'MSSubClass_2-1/2 Story', 'HouseStyle_2Story',
#        'Foundation_CBlock', 'LotArea', 'LotShape_Reg',
#        'Neighborhood_Edwards', 'BsmtFinType2',
#        'Exterior1st_Shingles-based', 'Neighborhood_CollgCr',
#        'Exterior2nd_Shingles-based', 'HouseStyle_2.5Unf',
#        'Neighborhood_NWAmes', 'Exterior1st_Other', 'Neighborhood_BrkSide',
#        'Remodeled', 'Fireplaces', 'Neighborhood_NridgHt',
#        'BldgType_TwnhsE', 'Exterior1st_Wood-based', 'LotFrontage',
#        'Neighborhood_IDOTRR', 'Neighborhood_Crawfor',
#        'Neighborhood_Sawyer', 'GarageType_Detchd', 'Exterior2nd_Other',
#        'remodel_time', 'BldgType_Twnhs', 'MasVnrType_BrkFace',
#        'Neighborhood_Gilbert', 'GarageType_NA', 'Neighborhood_BrDale',
#        'HouseStyle_2.5Fin', 'Neighborhood_SawyerW',
#        'Neighborhood_MeadowV', 'Neighborhood_SWISU',
#        'Neighborhood_Mitchel', 'LotConfig_CulDSac',
#        'Exterior1st_Metal-based', 'TotalBsmtSF', 'Neighborhood_NoRidge',
#        'Neighborhood_ClearCr', 'MasVnrType_Stone', 'BldgType_Duplex',
#        'Neighborhood_Timber', 'HouseStyle_SLvl', 'Foundation_Slab',
#        'Exterior2nd_Stone-based', 'Exterior1st_Stone-based',
#        'SaleCondition_Partial', 'Neighborhood_StoneBr', 'Fence',
#        'HouseStyle_SFoyer', 'Heating_Wall-Based', 'RoofStyle_Hip',
#        'LandContour_Low', 'Neighborhood_NPkVill', 'Alley_Pave',
#        'TotalPorchArea', 'PoolQC', 'GarageType_BuiltIn',
#        'BldgType_2fmCon', 'Neighborhood_Veenker', 'LotConfig_FR2',
#        'LandContour_HLS', 'Heating_Hot Water/Steam',
#        'SaleCondition_Alloca', 'LotShape_IR2', 'Electrical_Mix',
#        'MSZoning_RH', 'Condition1_Railroad Proximity',
#        'GarageType_Basment', 'SaleCondition_AdjLand',
#        'RoofMatl_Wood Roofing', 'LotShape_IR3',
#        'RoofMatl_Specialty Roofing', 'HouseStyle_1.5Unf', 'Functional',
#        'RoofStyle_Mansard', 'GarageType_CarPort', 'RoofStyle_Shed',
#        'RoofStyle_Gambrel', 'MiscFeature_Shed', 'SaleType_ConLD',
#        'Heating_Gravity-Based', 'Foundation_Stone', 'Foundation_Wood',
#        'Neighborhood_Blueste', 'SaleCondition_Family', 'MiscFeature_Othr',
#        'SaleType_Con', 'SaleType_ConLw', 'LotConfig_FR3',
#        'MiscFeature_TenC', 'SaleType_CWD', 'SaleType_Oth',
#        'SaleType_ConLI'], dtype=object)

# %%
x_train=training.loc[:,best_features]
y_train=training.loc[:,'SalePrice'].values
x_valid=validation.loc[:,best_features]
y_valid=validation.loc[:,'SalePrice'].values
x_test=test_data.loc[:,best_features]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_valid)

# %%
from sklearn.metrics import mean_squared_error, r2_score
# Evaluate the model
mse=mean_squared_error(np.log(100000*np.exp(y_valid)), np.log(100000*np.exp(y_pred)))
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", np.sqrt(mse))
print("R² Score:", r2_score(np.log(100000*np.exp(y_valid)), np.log(100000*np.exp(y_pred))))
# Out:
# Mean Squared Error: 0.02180282720506465
# Root Mean Squared Error: 0.14765780441637566
# R² Score: 0.8831658745316506

# %%
y_pred=model.predict(x_test)
y_pred=100000*np.exp(y_pred)
results=pd.read_csv('sample_submission.csv')
results['SalePrice']=y_pred
results.to_csv('submission_test_1.csv',index=False)

# %%
from sklearn.linear_model import Ridge, Lasso
model = Ridge(alpha=1.0)
model.fit(x_train, y_train)
y_pred = model.predict(x_valid)
mse=mean_squared_error(np.log(100000*np.exp(y_valid)), np.log(100000*np.exp(y_pred)))
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", np.sqrt(mse))
print("R² Score:", r2_score(np.log(100000*np.exp(y_valid)), np.log(100000*np.exp(y_pred))))
# Out:
# Mean Squared Error: 0.021008155630749533
# Root Mean Squared Error: 0.1449419043298022
# R² Score: 0.8874242561418162

# %%
coefficients = model.coef_
features = x_train.columns
coef_df = pd.DataFrame({
    'Feature': features,
    'Coefficient': coefficients
})

# Step 5: Show features used in the model (non-zero coefficients)
print(coef_df[coef_df['Coefficient'] != 0]['Feature'].values)
# Out:
# ['BldgType_Twnhs' '1stFlr_vs_2ndFlr' 'Neighborhood_NWAmes' 'BsmtFinSF1'
#  'Exterior1st_Cement-based' 'Neighborhood_Gilbert' 'Neighborhood_Sawyer'
#  'RoofStyle_Gambrel' 'Neighborhood_BrkSide' 'RoofMatl_Wood Roofing'
#  'Foundation_PConc' 'GarageArea' 'GarageCars' 'Neighborhood_NridgHt'
#  'HouseStyle_SFoyer' 'Neighborhood_Crawfor' 'MSZoning_RH'
#  'Neighborhood_IDOTRR' 'Foundation_CBlock' 'MSSubClass_2-1/2 Story'
#  'BsmtFinType1' 'Neighborhood_SawyerW' 'Exterior1st_Other' 'GarageAge'
#  'Neighborhood_Mitchel' 'Exterior2nd_Shingles-based' 'BsmtQual'
#  'FireplaceQu' 'CenturyBuilt' 'Neighborhood_NoRidge' 'SaleType_WD'
#  'Fireplaces' 'TotRmsAbvGrd' 'RoofStyle_Mansard' 'OverallQual'
#  'Exterior1st_Shingles-based' 'LotArea' 'HouseStyle_2.5Unf'
#  'Total_Bathrooms' 'GarageType_Basment' 'TotalBsmtSF' 'FullBath'
#  'Neighborhood_Timber' 'Neighborhood_SWISU' 'Neighborhood_ClearCr'
#  'remodel_time' 'ExterQual' 'Neighborhood_BrDale' 'Foundation_Slab'
#  'BsmtCond' 'Neighborhood_MeadowV' 'SaleCondition_Normal' 'KitchenQual'
#  'HouseStyle_2.5Fin' 'LandContour_Lvl' 'LotFrontage' 'GarageFinish'
#  'Condition1_Railroad Proximity' 'Condition1_Road Proximity'
#  'RoofStyle_Shed' 'Neighborhood_StoneBr' 'GarageType_CarPort' 'Alley_NA'
#  'MiscFeature_Othr' 'Alley_Pave' 'RoofMatl_Specialty Roofing' 'CentralAir'
#  'HeatingQC' 'OverallCond' 'LandContour_Low' 'Neighborhood_Veenker'
#  'LandContour_HLS' 'Neighborhood_NPkVill' 'LotConfig_CulDSac'
#  'BsmtExposure' 'Exterior2nd_Stone-based' 'Remodeled' 'MiscFeature_TenC'
#  'PavedDrive' 'LotConfig_Inside' 'Exterior1st_Stone-based'
#  'SaleType_ConLD' 'Heating_Wall-Based' 'PoolQC' 'LotShape_Reg'
#  'Heating_Hot Water/Steam' 'TotalPorchArea' 'SaleCondition_AdjLand'
#  'ExterCond' 'SaleCondition_Alloca' 'HouseStyle_1.5Unf'
#  'SaleCondition_Family' 'LotConfig_FR2' 'LotShape_IR3' 'Functional'
#  'BsmtFinType2' 'Fence' 'Heating_Gravity-Based' 'Foundation_Stone'
#  'LotShape_IR2' 'SaleType_ConLw' 'SaleType_CWD' 'Foundation_Wood'
#  'Neighborhood_Blueste' 'SaleType_ConLI' 'SaleType_Con' 'SaleType_Oth'
#  'LotConfig_FR3']

# %%
y_pred=model.predict(x_test)
y_pred=100000*np.exp(y_pred)
results=pd.read_csv('sample_submission.csv')
results['SalePrice']=y_pred
results.to_csv('submission_test_2.csv',index=False)

# %%
model = Lasso(alpha=0.001)
model.fit(x_train, y_train)
y_pred = model.predict(x_valid)
mse=mean_squared_error(np.log(100000*np.exp(y_valid)), np.log(100000*np.exp(y_pred)))
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", np.sqrt(mse))
print("R² Score:", r2_score(np.log(100000*np.exp(y_valid)), np.log(100000*np.exp(y_pred))))
# Out:
# Mean Squared Error: 0.020899412734718997
# Root Mean Squared Error: 0.14456629183429653
# R² Score: 0.8880069732839156

# %%
coefficients = model.coef_
features = x_train.columns
coef_df = pd.DataFrame({
    'Feature': features,
    'Coefficient': coefficients
})

# Step 5: Show features used in the model (non-zero coefficients)
print(coef_df[coef_df['Coefficient'] != 0]['Feature'].values)
# Out:
# ['1stFlr_vs_2ndFlr' 'BsmtFinSF1' 'Neighborhood_Gilbert'
#  'Neighborhood_BrkSide' 'Foundation_PConc' 'GarageArea' 'GarageCars'
#  'Neighborhood_NridgHt' 'Neighborhood_Crawfor' 'Neighborhood_IDOTRR'
#  'Foundation_CBlock' 'BsmtFinType1' 'GarageAge' 'BsmtQual' 'FireplaceQu'
#  'Neighborhood_NoRidge' 'SaleType_WD' 'Fireplaces' 'TotRmsAbvGrd'
#  'OverallQual' 'LotArea' 'Total_Bathrooms' 'TotalBsmtSF' 'FullBath'
#  'Neighborhood_ClearCr' 'remodel_time' 'ExterQual' 'Foundation_Slab'
#  'BsmtCond' 'SaleCondition_Normal' 'KitchenQual' 'LotFrontage'
#  'GarageFinish' 'Condition1_Road Proximity' 'Neighborhood_StoneBr'
#  'Alley_Pave' 'RoofMatl_Specialty Roofing' 'CentralAir' 'HeatingQC'
#  'OverallCond' 'LotConfig_CulDSac' 'BsmtExposure' 'Remodeled' 'PavedDrive'
#  'PoolQC' 'TotalPorchArea' 'ExterCond' 'LotConfig_FR2' 'LotShape_IR3'
#  'Functional' 'BsmtFinType2' 'Fence']

# %%
y_pred=model.predict(x_test)
y_pred=100000*np.exp(y_pred)
results=pd.read_csv('sample_submission.csv')
results['SalePrice']=y_pred
results.to_csv('submission_test_3.csv',index=False)
