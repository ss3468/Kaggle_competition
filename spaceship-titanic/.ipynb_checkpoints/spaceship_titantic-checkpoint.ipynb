# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import *

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

# %%
#EDA
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate counts of each category
counts = train_data['Transported'].value_counts()
print(counts)

# Plotting
plt.figure(figsize=(6, 6))
counts.plot(kind='bar')
plt.title('Distribution of Binary Output')
plt.xlabel('Categories')
plt.ylabel('Counts')
plt.xticks(rotation=0)  # Rotate x-labels if needed
plt.show()
# Out:
# Transported
# True     4378
# False    4315
# Name: count, dtype: int64

# %%
nulls = train_data.isnull().sum().to_frame()
for index, row in nulls.iterrows():
    if row[0] > 0:
        print(index, row[0])
    else:
        continue
# Out:
# HomePlanet 201
# CryoSleep 217
# Cabin 199
# Destination 182
# Age 179
# VIP 203
# RoomService 181
# FoodCourt 183
# ShoppingMall 208
# Spa 183
# VRDeck 188
# Name 200

# %%
X = train_data.drop('Transported', axis=1)
y = train_data['Transported']
# Split the data into training and testing sets with stratification
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, stratify=y, random_state=21)

# Creating dataframes from the split data
train_df = pd.concat([X_train, y_train], axis=1)
valid_df = pd.concat([X_valid, y_valid], axis=1)

# %%
nulls = train_df.isnull().sum().to_frame()
for index, row in nulls.iterrows():
    if row[0] > 0:
        print(index,row[0],row[0]/len(train_df))
    else:
        continue
# Out:
# HomePlanet 159 0.02286453839516825
# CryoSleep 175 0.025165372447512224
# Cabin 160 0.02300834052343975
# Destination 140 0.02013229795800978
# Age 148 0.021282714984181765
# VIP 160 0.02300834052343975
# RoomService 139 0.01998849582973828
# FoodCourt 149 0.021426517112453265
# ShoppingMall 172 0.02473396606269773
# Spa 146 0.02099511072763877
# VRDeck 150 0.021570319240724764
# Name 152 0.02185792349726776

# %%
nulls = valid_df.isnull().sum().to_frame()
for index, row in nulls.iterrows():
    if row[0] > 0:
        print(index, row[0])
    else:
        continue
# Out:
# HomePlanet 42
# CryoSleep 42
# Cabin 39
# Destination 42
# Age 31
# VIP 43
# RoomService 42
# FoodCourt 34
# ShoppingMall 36
# Spa 37
# VRDeck 38
# Name 48

# %%
nulls = test_data.isnull().sum().to_frame()
for index, row in nulls.iterrows():
    if row[0] > 0:
        print(index, row[0])
    else:
        continue
# Out:
# HomePlanet 87
# CryoSleep 93
# Cabin 100
# Destination 92
# Age 91
# VIP 93
# RoomService 82
# FoodCourt 106
# ShoppingMall 98
# Spa 101
# VRDeck 80
# Name 94

# %%
train_df.to_csv('training.csv',index=False)
valid_df.to_csv('validation.csv',index=False)
test_data.to_csv('testing.csv',index=False)

# %%
from data_preprocessing import *
train_df,valid_df,test_data=preprocess_data(train_df,test_data,valid_df)
train_df.to_csv('training_post.csv',index=False)
valid_df.to_csv('valid_post.csv',index=False)
test_data.to_csv('test_post.csv',index=False)

# %%
nulls = train_df.isnull().sum().to_frame()
for index, row in nulls.iterrows():
    if row[0] > 0:
        print(index, row[0])
    else:
        continue
# Out:
# Age 148
# VIP 160
# RoomService 139
# FoodCourt 149
# ShoppingMall 172
# Spa 146
# VRDeck 150
# Surname 152
# deck 160
# num 160
# side 160

# %%
nulls = valid_df.isnull().sum().to_frame()
for index, row in nulls.iterrows():
    if row[0] > 0:
        print(index, row[0])
    else:
        continue
# Out:
# Age 31
# VIP 43
# RoomService 42
# FoodCourt 34
# ShoppingMall 36
# Spa 37
# VRDeck 38
# Surname 48
# deck 39
# num 39
# side 39

# %%
nulls = test_data.isnull().sum().to_frame()
for index, row in nulls.iterrows():
    if row[0] > 0:
        print(index, row[0])
    else:
        continue
# Out:
# Age 91
# VIP 93
# RoomService 82
# FoodCourt 106
# ShoppingMall 98
# Spa 101
# VRDeck 80
# Surname 94
# deck 100
# num 100
# side 100

# %%
pd.crosstab([train_df['deck'],train_df['Destination'],train_df['CryoSleep']], train_df['HomePlanet'])
# Out:
# HomePlanet                    Earth  Europa  Mars
# deck Destination   CryoSleep
# A    55 Cancri e   False          0      58     0
#                    True           0      26     0
#      PSO J318.5-22 False          0       1     0
#      TRAPPIST-1e   False          0      81     0
#                    True           0      28     0
# B    55 Cancri e   False          0     109     0
#                    True           0     159     0
#      PSO J318.5-22 False          0       1     0
#                    True           0       1     0
#      TRAPPIST-1e   False          0     180     0
#                    True           0     190     0
# C    55 Cancri e   False          0     136     0
#                    True           0     125     0
#      PSO J318.5-22 False          0       3     0
#                    True           0       5     0
#      TRAPPIST-1e   False          0     214     0
#                    True           0     115     0
# D    55 Cancri e   False          0      31    29
#                    True           0      25    10
#      PSO J318.5-22 False          0       0    16
#      TRAPPIST-1e   False          0      56   158
#                    True           0      30    17
# E    55 Cancri e   False         33      17    11
#                    True           3      19     5
#      PSO J318.5-22 False         20       0     4
#                    True           0       0     8
#      TRAPPIST-1e   False        255      49   167
#                    True           7      26    78
# F    55 Cancri e   False        217       0    48
#                    True           3       0    51
#      PSO J318.5-22 False        165       0    14
#                    True           2       0     4
#      TRAPPIST-1e   False        911       0   414
#                    True           4       0   384
# G    55 Cancri e   False        134       0     0
#                    True         160       0     0
#      PSO J318.5-22 False         82       0     0
#                    True         285       0     0
#      TRAPPIST-1e   False        747       0     0
#                    True         660       0     0
# T    TRAPPIST-1e   False          0       3     0

# %%
pd.crosstab(train_df['deck'], train_df['HomePlanet'])
# Out:
# HomePlanet  Earth  Europa  Mars
# deck
# A               0     194     0
# B               0     640     0
# C               0     598     0
# D               0     142   230
# E             318     111   273
# F            1302       0   915
# G            2068       0     0
# T               0       3     0
